# %% [markdown]
# <a href="https://colab.research.google.com/github/ChandraMouli-13/TumorSegmentation/blob/main/CVProject1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]])
# Out:
# OneHotEncoder()

# %%
data = []
paths = []
result = []

for r, d, f in os.walk(r'/content/drive/MyDrive/Tumor Dataset/archive (1)/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
paths = []
for r, d, f in os.walk(r"/content/drive/MyDrive/Tumor Dataset/archive (1)/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 128, 128, 32)      416
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 32)      4128
#
#  batch_normalization (Batch  (None, 128, 128, 32)      128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 64, 64, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 64)        8256
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 64)        16448
#
#  batch_normalization_1 (Bat  (None, 64, 64, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 32, 32, 64)        0
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense (Dense)               (None, 512)               33554944
#
# ...

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 15s 4s/step - loss: 0.0368 - val_loss: 4.1490
# Epoch 2/30
# 3/3 [==============================] - 14s 4s/step - loss: 0.0050 - val_loss: 4.0217
# Epoch 3/30
# 3/3 [==============================] - 9s 3s/step - loss: 1.1804e-05 - val_loss: 3.9184
# Epoch 4/30
# 3/3 [==============================] - 7s 2s/step - loss: 8.7963e-05 - val_loss: 3.8293
# Epoch 5/30
# 3/3 [==============================] - 9s 3s/step - loss: 1.3864e-06 - val_loss: 3.7521
# Epoch 6/30
# 3/3 [==============================] - 8s 3s/step - loss: 3.9426e-04 - val_loss: 3.6827
# Epoch 7/30
# 3/3 [==============================] - 8s 2s/step - loss: 0.0113 - val_loss: 3.5480
# Epoch 8/30
# 3/3 [==============================] - 9s 3s/step - loss: 4.7405e-06 - val_loss: 3.4127
# Epoch 9/30
# 3/3 [==============================] - 7s 2s/step - loss: 0.0548 - val_loss: 3.2391
# Epoch 10/30
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Test', 'Validation'], loc='upper right')
plt.show()

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/content/drive/MyDrive/Tumor Dataset/archive (1)/no/13 no.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"/content/drive/MyDrive/Tumor Dataset/archive (1)/yes/Y154.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 100.0% Confidence This Is A Its a Tumor
